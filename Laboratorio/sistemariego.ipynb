# %%
### Laboratorio 2
#01/09/26
#Joselin Rosiles Rivera

# %%
#problema Realizar un sistema que identifique si una planta necesita riego para activar el sensor
#nivel humedad suelo
#si el nivel de humedad es menor al 40% la planta necesita riego
#si el nivel de humedad es igual o mayor al 40%, la planta no necesita riego

# %%
print ("mi primer sistema de riego")
planta=input ("Escriba el nombre de la planta")
humedad=float (input("Ingresa el nivel de humedad de la planta"))
print ("Datos almacenados")
print ("Planta:",planta)
print ("Humedad:", humedad)
if humedad <40:
    print("la planta necesita riego")
elif humedad >=40:
    print("la planta no necesita riego")
# Out:
# mi primer sistema de riego
# Escriba el nombre de la planta captus
# Ingresa el nivel de humedad de la planta 30
# Datos almacenados
# Planta: captus
# Humedad: 30.0
# la planta necesita riego
